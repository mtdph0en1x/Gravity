# %%
import pandas as pd

# %%
df = pd.read_csv('all_tracks.csv')

# %%
df.head()
# Out:
#    source_file     name  level  track_id  start_x  start_y  finish_x  \
# 0            1    Intro      0         0      -49       24       433
# 1            1   Shorty      0         1     -196      -46       336
# 2            1    Slope      0         2     -612     -665       623
# 3            1  Crackle      0         3     -338      -49       341
# 4            1   Knolls      0         4     -168       23       850
#
#    finish_y  point_count                                           points_x  \
# 0         0           45  -380|-305|-272|-249|-239|-221|-201|-176|-108|-...
# 1         0           40  -438|-383|-335|-309|-292|-255|-222|-192|-160|-...
# 2         0           83  -1002|-851|-806|-777|-743|-698|-643|-579|-536|...
# 3         0           51  -640|-592|-552|-487|-467|-446|-414|-372|-327|-...
# 4         0           77  -411|-353|-344|-277|-265|-232|-227|-206|-198|-...
#
#                                             points_y
# 0  136|133|118|91|65|42|23|12|6|6|9|5|-8|-31|-40|...
# 1  -7|-40|-56|-43|-25|-49|-64|-64|-64|-72|-82|-77...
# 2  -505|-537|-560|-613|-647|-674|-683|-682|-695|-...
# 3  -44|-56|-57|-48|-41|-27|-47|-65|-67|-62|-70|-7...
# 4  49|70|71|70|67|56|51|7|2|5|5|1|3|14|41|46|47|4...

# %%
#parsing points
df['points_x_parsed'] = df['points_x'].str.split('|').apply(lambda x: [float(coord) for coord in x])
df['points_y_parsed'] = df['points_y'].str.split('|').apply(lambda x: [float(coord) for coord in x])

# %%
print(f"Track: {df.iloc[0]['name']}")
print(f"X coordinates : {df.iloc[0]['points_x_parsed']}")
print(f"Y coordinates : {df.iloc[0]['points_y_parsed']}")
# Out:
# Track: Intro
# X coordinates : [-380.0, -305.0, -272.0, -249.0, -239.0, -221.0, -201.0, -176.0, -108.0, -64.0, -50.0, -36.0, -6.0, 39.0, 81.0, 108.0, 121.0, 137.0, 149.0, 164.0, 193.0, 216.0, 244.0, 270.0, 293.0, 312.0, 328.0, 342.0, 362.0, 381.0, 406.0, 440.0, 462.0, 483.0, 502.0, 517.0, 533.0, 544.0, 551.0, 563.0, 592.0, 625.0, 668.0, 706.0, 798.0]
# Y coordinates : [136.0, 133.0, 118.0, 91.0, 65.0, 42.0, 23.0, 12.0, 6.0, 6.0, 9.0, 5.0, -8.0, -31.0, -40.0, -42.0, -38.0, -30.0, -46.0, -37.0, -45.0, -52.0, -55.0, -55.0, -47.0, -35.0, -23.0, -12.0, -1.0, 6.0, 7.0, 4.0, 3.0, 10.0, 24.0, 41.0, 56.0, 77.0, 101.0, 121.0, 137.0, 139.0, 135.0, 121.0, 67.0]

# %%
df.drop(['points_x','points_y'], axis=1, inplace=True)

# %%
df
# Out:
#        source_file           name  level  track_id  start_x  start_y  \
# 0                1          Intro      0         0      -49       24
# 1                1         Shorty      0         1     -196      -46
# 2                1          Slope      0         2     -612     -665
# 3                1        Crackle      0         3     -338      -49
# 4                1         Knolls      0         4     -168       23
# ...            ...            ...    ...       ...      ...      ...
# 17845          997  Round 3: Hard      2         0        0        0
# 17846          997       Original      2         1        0        0
# 17847          997       Golstein      2         2        0        0
# 17848          997       Number 2      2         3        0        0
# 17849          997       Original      2         4        0        0
#
#        finish_x  finish_y  point_count  \
# 0           433         0           45
# 1           336         0           40
# 2           623         0           83
# 3           341         0           51
# 4           850         0           77
# ...         ...       ...          ...
# 17845      2993         0          386
# 17846      1505         0          381
# 17847      1505         0          353
# 17848      1257         0          356
# 17849       497         0          664
#
#                                          points_x_parsed  \
# 0      [-380.0, -305.0, -272.0, -249.0, -239.0, -221....
# 1      [-438.0, -383.0, -335.0, -309.0, -292.0, -255....
# 2      [-1002.0, -851.0, -806.0, -777.0, -743.0, -698...
# 3      [-640.0, -592.0, -552.0, -487.0, -467.0, -446....
# 4      [-411.0, -353.0, -344.0, -277.0, -265.0, -232....
# ...                                                  ...
# 17845  [-96.0, -92.0, -86.0, -85.0, -84.0, -83.0, -82...
# 17846  [-96.0, -95.0, -87.0, -86.0, -85.0, -84.0, -83...
# 17847  [-96.0, -95.0, -85.0, -84.0, -75.0, -74.0, -73...
# 17848  [-96.0, -89.0, -87.0, -86.0, -83.0, -80.0, -79...
# 17849  [-96.0, -95.0, -93.0, -88.0, -87.0, -86.0, -79...
#
#                                          points_y_parsed
# 0      [136.0, 133.0, 118.0, 91.0, 65.0, 42.0, 23.0, ...
# 1      [-7.0, -40.0, -56.0, -43.0, -25.0, -49.0, -64....
# 2      [-505.0, -537.0, -560.0, -613.0, -647.0, -674....
# 3      [-44.0, -56.0, -57.0, -48.0, -41.0, -27.0, -47...
# 4      [49.0, 70.0, 71.0, 70.0, 67.0, 56.0, 51.0, 7.0...
# ...                                                  ...
# 17845  [35.0, -5.0, 18.0, 18.0, 2.0, -6.0, 10.0, 7.0,...
# 17846  [-25.0, -25.0, -53.0, -29.0, -45.0, -63.0, -28...
# 17847  [-13.0, -13.0, -71.0, 2.0, 2.0, -70.0, 1.0, 1....
# 17848  [-65.0, -87.0, -81.0, -75.0, -82.0, -88.0, -88...
# 17849  [-15.0, -26.0, -22.0, -20.0, -30.0, -32.0, -28...
#
# [17850 rows x 11 columns]

# %%
def get_meaningful_region_of_a_track(points_x, points_y, start_x, finish_x):
    #convert to a numpy array
    points_x = np.array(points_x)
    points_y = np.array(points_y)
    
    #find closest points to the start/finish
    start_distances = np.abs(points_x - start_x)
    finish_distances = np.abs(points_x - finish_x)
    
    #ids of those points 
    start_idx = np.argmin(start_distances)
    finish_idx = np.argmin(finish_distances)
    
    #ensure that we are  going from start to finish
    if start_idx > finish_idx:
        start_idx, finish_idx = finish_idx, start_idx
    #extract the racing segment between start and finish X-coordinates
    racing_x = points_x[start_idx:finish_idx + 1]
    racing_y = points_y[start_idx:finish_idx + 1]
    
    return racing_x, racing_y

# %%
import numpy as np

def get_track_length(points_x, points_y, start_x, finish_x):
    """
    Calculate track distances using meaningful regions:
    - Straight distance: horizontal span between start_x and finish_x
    - Track length: actual path length between closest X-coordinates
    - Efficiency - ratio between two on the top
    """
    #get meaningful regions of a track
    racing_x, racing_y = get_meaningful_region_of_a_track(
        points_x, points_y, start_x, finish_x
    )
    
    
    #calculate actual track length (sum of segment distances)
    if len(racing_x) > 1:
        dx = np.diff(racing_x)
        dy = np.diff(racing_y)
        track_length = np.sum(np.sqrt(dx**2 + dy**2))
    else:
        track_length = 0
    
    #straight line distance (horizontal span)
    straight_distance = abs(finish_x - start_x)
    
    #efficiency ratio (how simple the track is)
    efficiency = straight_distance / track_length if track_length > 0 else 0
    
    return pd.Series([track_length, straight_distance, efficiency])

df[['actual_track_length', 'straight_distance', 'track_efficiency']] = df.apply(
    lambda row: get_track_length(
        row['points_x_parsed'], 
        row['points_y_parsed'],
        row['start_x'],
        row['finish_x']
    ), axis=1
)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_track(points_x, points_y, start_x, start_y, finish_x, finish_y, title):
    '''A quick look into how track looks like'''
    plt.figure(figsize=(12, 6))
    plt.plot(points_x, points_y, 'b-', linewidth=2, label='Track')

    #start/finish coordinates
    plt.scatter(start_x, start_y, color='green', s=100, label='Start', marker='o', edgecolor='black', linewidth=2)
    plt.scatter(finish_x, finish_y, color='red', s=100, label='Finish', marker='s', edgecolor='black', linewidth=2)
    #get meaningful regions of a track
    racing_x, racing_y = get_meaningful_region_of_a_track(
        points_x, points_y, start_x, finish_x
    )
    
    
    plt.scatter(racing_x[0], racing_y[0], color='black', s=100, label='Start', marker='p', edgecolor='white', linewidth=2)
    plt.scatter(racing_x[-1], racing_y[-1], color='white', s=100, label='Finish', marker='P', edgecolor='black', linewidth=2)
    
    plt.title(title)
    plt.xlabel('X coordinate')
    plt.ylabel('Y coordinate')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.axis('equal')
    plt.show()


def plot_track_from_df(df, index):
    '''Plot track using dataframe row'''
    row = df.iloc[index]
    plot_track(
        points_x=row['points_x_parsed'],
        points_y=row['points_y_parsed'],
        start_x=row['start_x'],
        start_y=row['start_y'],
        finish_x=row['finish_x'],
        finish_y=row['finish_y'],
        title=f"Track: {row['name']} (Level: {row['level']})"
    )

# %%
plot_track_from_df(df, 697)

# %%
# Data quality checks
print(f"Total tracks: {len(df)}")
print(f"Unique track names: {df['name'].nunique()}")
print(f"Duplicate track names: {len(df) - df['name'].nunique()}")
# Out:
# Total tracks: 17850
# Unique track names: 11512
# Duplicate track names: 6338

# %%
df.drop_duplicates(subset=['name'], keep='first', inplace=True)

# %%
def analyze_track_terrain(points_x, points_y,start_x,finish_x):
    """
    Analyze terrain with total climb/drop distances
    """
    #get meaningful regions of a track
    racing_x, racing_y = get_meaningful_region_of_a_track(
        points_x, points_y, start_x, finish_x
    )
    
    
    if len(racing_x) < 3:
        return pd.Series([0] * 8)
        
    dx=np.diff(racing_x)
    dy=np.diff(racing_y)
    #calculate segment distances
    segment_distances = np.sqrt(dx**2 + dy**2)
    
    #basic counts between each two points
    climbs = np.sum(dy > 0)
    drops = np.sum(dy < 0)
    flat_sections = np.sum(dy == 0)
    
    climb_distance = np.sum(segment_distances[dy > 0])  # total distance while climbing
    drop_distance = np.sum(segment_distances[dy < 0])   # total distance while dropping
    flat_distance = np.sum(segment_distances[dy == 0])  # total distance on flat
    
    # significant changes in steepness counts
    steep_climbs = np.sum(dy > 50)
    steep_drops = np.sum(dy < -50)

    y_variance = np.var(racing_y)
    elevation_range= np.max(racing_y) - np.min(racing_y)
    
    return pd.Series([
        climbs, drops, flat_sections,
        climb_distance, drop_distance, flat_distance,
        steep_climbs, steep_drops,y_variance,elevation_range
    ])

terrain_features = [
    'climbs', 'drops', 'flat_sections',
    'climb_distance', 'drop_distance', 'flat_distance',
    'steep_climbs', 'steep_drops','y_variance','elevation_range'
]

df[terrain_features] = df.apply(
    lambda row: analyze_track_terrain(row['points_x_parsed'], row['points_y_parsed'],row['start_x'],row['finish_x']), 
    axis=1
)

# %%
plot_track_from_df(df,978)

# %%
df[df['elevation_range']==0 ].count()
# Out:
# source_file            17
# name                   17
# level                  17
# track_id               17
# start_x                17
# start_y                17
# finish_x               17
# finish_y               17
# point_count            17
# points_x_parsed        17
# points_y_parsed        17
# actual_track_length    17
# straight_distance      17
# track_efficiency       17
# climbs                 17
# drops                  17
# flat_sections          17
# climb_distance         17
# drop_distance          17
# flat_distance          17
# steep_climbs           17
# steep_drops            17
# y_variance             17
# elevation_range        17
# dtype: int64

# %%
df[df['elevation_range']<0 ].count()
# Out:
# source_file            0
# name                   0
# level                  0
# track_id               0
# start_x                0
# start_y                0
# finish_x               0
# finish_y               0
# point_count            0
# points_x_parsed        0
# points_y_parsed        0
# actual_track_length    0
# straight_distance      0
# track_efficiency       0
# climbs                 0
# drops                  0
# flat_sections          0
# climb_distance         0
# drop_distance          0
# flat_distance          0
# steep_climbs           0
# steep_drops            0
# y_variance             0
# elevation_range        0
# dtype: int64

# %%
def count_direction_changes(points_x, points_y, start_x, finish_x, threshold=60):
    """Count significant direction changes in track"""
    if len(points_x) < 3:
        return 0
        
    racing_x, racing_y = get_meaningful_region_of_a_track(
        points_x, points_y, start_x, finish_x
    )
    
    changes = 0
    for i in range(2, len(racing_x)):
        # Calculate vectors
        v1 = (racing_x[i-1] - racing_x[i-2], racing_y[i-1] - racing_y[i-2])
        v2 = (racing_x[i] - racing_x[i-1], racing_y[i] - racing_y[i-1])
        
        # Calculate angle change
        angle_change = np.arccos(np.clip(
            np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)), -1, 1
        )) * 180 / np.pi
        
        if angle_change > threshold:
            changes += 1
    
    return changes

df['direction_changes']=df.apply(
    lambda row: count_direction_changes(row['points_x_parsed'], row['points_y_parsed'],row['start_x'],row['finish_x']), 
    axis=1
)
# Out:
# C:\Users\Ruslan\AppData\Local\Temp\ipykernel_16608\1049801110.py:18: RuntimeWarning: invalid value encountered in scalar divide
#   np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)), -1, 1

# %%
features=['actual_track_length', 'straight_distance',
       'track_efficiency', 'y_variance', 'elevation_range', 'climbs', 'drops',
       'flat_sections', 'climb_distance', 'drop_distance', 'flat_distance',
       'steep_climbs', 'steep_drops','direction_changes']

# %%
df[features]
# Out:
#        actual_track_length  straight_distance  track_efficiency    y_variance  \
# 0               531.942570              482.0          0.906113    488.652893
# 1               665.045277              532.0          0.799946   1325.782544
# 2              1470.136398             1235.0          0.840058    940.390266
# 3               726.164694              679.0          0.935050    719.837370
# 4              1232.506129             1018.0          0.825959   1057.784780
# ...                    ...                ...               ...           ...
# 17843          5247.670707             1505.0          0.286794  24871.794761
# 17844          4830.273191             1505.0          0.311577  12685.291532
# 17845          5704.445998             2993.0          0.524678  13418.873555
# 17847          4003.010613             1505.0          0.375967  30055.888537
# 17848          3646.810238             1257.0          0.344685  19632.281675
#
#        elevation_range  climbs  drops  flat_sections  climb_distance  \
# 0                 64.0    10.0   10.0            1.0      201.705033
# 1                112.0    13.0   10.0            2.0      312.424130
# 2                116.0    31.0   28.0            6.0      670.083173
# 3                 88.0    18.0   14.0            1.0      418.867501
# 4                132.0    32.0   24.0            1.0      672.195927
# ...                ...     ...    ...            ...             ...
# 17843            586.0   113.0  151.0           29.0     2344.747274
# 17844            489.0    85.0  114.0           28.0     2055.027550
# 17845            490.0    96.0   96.0          121.0     2315.500516
# 17847            613.0    99.0  141.0           56.0     1550.396681
# 17848            518.0    90.0  119.0           32.0     1587.330360
#
#        drop_distance  flat_distance  steep_climbs  steep_drops  \
# 0         304.237537           26.0           0.0          0.0
# 1         295.621148           57.0           0.0          0.0
# 2         670.053225          130.0           0.0          0.0
# 3         295.297193           12.0           0.0          0.0
# 4         548.310202           12.0           0.0          0.0
# ...              ...            ...           ...          ...
# 17843    2794.923433          108.0           8.0          7.0
# 17844    2364.245642          411.0           8.0          8.0
# 17845    2297.945482         1091.0           4.0          5.0
# 17847    2131.613931          321.0           0.0          3.0
# 17848    1862.479877          197.0           3.0          2.0
#
#        direction_changes
# 0                      2
# 1                      6
# 2                      1
# 3                      1
# 4                      0
# ...                  ...
# 17843                143
# 17844                118
# 17845                182
# 17847                130
# 17848                103
#
# [11512 rows x 14 columns]

# %%
corr_matrix = df[features].corr()
    
plt.figure(figsize=(12,10))
    

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
    

sns.heatmap(
    corr_matrix,
    mask=mask, 
    annot=True,  
    cmap='RdBu_r',  
    center=0,  
    square=True,  
    fmt='.2f',  
    cbar_kws={"shrink": .8}
)
    
plt.title('Track Features Correlation Matrix', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# %%
plot_track_from_df(df,978)

# %%
def remove_spikes(points_x,points_y,start_x,finish_x):
    
    x=np.array(points_x)
    y=np.array(points_y)
    if len(points_x) < 3:
        return pd.Series([0] * 2)
        
    dx = np.diff(x) 
    dy = np.diff(y) 
    
    removed_idx = []
    
    for i in range(0,len(dx)-1):
        if (dx[i]+dx[i+1])*5<(dy[i]+dy[i+1]):  # ((x[i+1] - x[i]) + (x[i+2] - x[i+1])) * threshold < ((y[i+1] - y[i]) + (y[i+2] - y[i+1]))
            removed_idx.append(i)

            
    keep_idx = [i for i in range(len(x)) if i not in removed_idx]
    cleaned_x = x[keep_idx]
    cleaned_y = y[keep_idx]

    return pd.Series([cleaned_x, cleaned_y])

clean_track=['cleaned_x','cleaned_y']
df[clean_track]=df.apply(
    lambda row: remove_spikes(row['points_x_parsed'], row['points_y_parsed'],row['start_x'],row['finish_x']), 
    axis=1
)

# %%
def plot_track_from_df_cleaned(df, index):
    '''Plot track using dataframe row'''
    row = df.iloc[index]
    plot_track(
        points_x=row['cleaned_x'],
        points_y=row['cleaned_y'],
        start_x=row['start_x'],
        start_y=row['start_y'],
        finish_x=row['finish_x'],
        finish_y=row['finish_y'],
        title=f"Cleaned track: {row['name']} (Level: {row['level']})"
    )

# %%
plot_track_from_df(df,978)
plot_track_from_df_cleaned(df,978)
